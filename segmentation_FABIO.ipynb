# %% [markdown]
# **Ressources**
#
# - [Convert Pandas DF into TF Dataset](https://medium.com/when-i-work-data/converting-a-pandas-dataframe-into-a-tensorflow-dataset-752f3783c168)
# -

# %%
#!pip install segmentation-models

# %%
# remove file directory for changed test run
# !rm -r data/segmentation

# %%
import tensorflow as tf
from tensorflow_examples.models.pix2pix import pix2pix
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from IPython.display import clear_output

import matplotlib.pyplot as plt

import pandas as pd
import numpy as np
import os
import shutil
import cv2
import time

from sklearn.model_selection import train_test_split

# %%
# self-written scripts
import sys
sys.path.insert(0, 'Python_Scripts')

import util
import surf_handling
import surf_hog_analysis
import mask_conversion
import data_preparation_cnn

# %%
DIMENSION = (256, 1600)
SEED = 42
BATCH_SIZE = 32

# %% [markdown]
# ---
#
# ### Data Preparations

# %%
df = pd.read_csv('data/train_complete.csv')
df.head(2)
# Out:
#                                             FilePath        ImageId  ClassId  \
# 0  /Users/fabioteichmann/neuefische/projects/Caps...  0002cc93b.jpg        1
# 1  /Users/fabioteichmann/neuefische/projects/Caps...  0007a71bf.jpg        3
#
#                                        EncodedPixels  Defect
# 0  29102 12 29346 24 29602 24 29858 24 30114 24 3...       1
# 1  18661 28 18863 82 19091 110 19347 110 19603 11...       1

# %%
def add_mask_to_df(df):
    # Generate `masks` for every image
    masks = []

    for i in range(len(df.ClassId)):
        #print(defects.EncodedPixels[i])
        encoded_pixels = df.EncodedPixels[i]
        class_id = df.ClassId[i]
        mask = mask_conversion.decode_pixel(image_dimension=DIMENSION, 
                                            encoded_pixels=encoded_pixels, 
                                            class_id=class_id)
        masks.append([mask.reshape(mask.shape[0]*mask.shape[1])])


    masks_ = pd.DataFrame(masks, columns=['Mask'])
    
    return df.join(masks_)

# %%
# create data frame for defective pictures with added `Mask`
defects = df.query('Defect == 1')
defects.head(2)
# Out:
#                                             FilePath        ImageId  ClassId  \
# 0  /Users/fabioteichmann/neuefische/projects/Caps...  0002cc93b.jpg        1
# 1  /Users/fabioteichmann/neuefische/projects/Caps...  0007a71bf.jpg        3
#
#                                        EncodedPixels  Defect
# 0  29102 12 29346 24 29602 24 29858 24 30114 24 3...       1
# 1  18661 28 18863 82 19091 110 19347 110 19603 11...       1

# %% [markdown]
# ---
#
# ### First Attempt only `ClassId` 2

# %%
import warnings
warnings.filterwarnings("ignore")

generate_mask_images(Xy_train, 2)
generate_mask_images(Xy_test, 2, train=False)

# %% [markdown]
# #### Augment images and masks

# %%
#!pip install -U albumentations --no-binary qudida,albumentations

# %% [markdown]
# [Albumentations Doku](https://albumentations.ai/docs/getting_started/mask_augmentation/)

# %% [markdown]
# ---
#
# ### Preparation for CNN Model

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
data_preparation_cnn.prepare_data_for_class_id(df=defects, 
                                               image_dimension=DIMENSION, 
                                               seed=SEED, 
                                               class_id=3, 
                                               inverse_masks=True)
# Out:
# Starting data preparations
# --------------------------------------------------
# preparing folders...
# base folder structure exists
# sub-folder structure for ClassId 3 created
# sub-foder structure for testing for ClassId 3 created
# Successfully created the directories
#
# copying images to folders...
# Images successfully copied to segmentation!
#
# generating mask images for ClassId 3 images...
# [ WARN:0@16.034] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/0007a71bf.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.039] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/0014fce06.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.043] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/0025bde0c.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.051] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/0046839bd.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.057] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/005d86c25.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.085] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/005f02e20.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.089] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/005f19695.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.098] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/0088260da.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.115] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/008d0f87b.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.121] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/0095cd374.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.126] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/00af2671f.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.136] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/00bf8497a.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.140] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/00cdb56a0.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.143] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/00d639396.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.155] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/00e0398ad.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.174] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/00ec97699.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.179] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/00f1665e6.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.186] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/00f6e702c.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.190] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/012d29df4.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.218] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/012f26693.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.223] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/01338c0ea.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.228] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/0139dd004.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.232] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/0141c9bf3.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.237] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/0148e9891.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.242] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/014ebe543.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.247] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/01540cab1.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.255] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/016af13d0.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.263] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/01764ee81.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.277] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/01919944c.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.301] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/019f42c2a.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.318] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/01a1027ce.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.324] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/01b043500.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.330] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/01b492dd6.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.334] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/01c3ef286.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.338] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/01cf446d4.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.342] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/01cfacf80.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.350] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/01e020dc5.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.366] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/01ebe0d32.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.375] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/01fd320c9.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.380] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/01fd50e68.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.388] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/020ff3106.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.393] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/0217af9b1.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.397] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/02291e913.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.401] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/02431211b.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.408] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/025cb9f6e.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.414] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/025dc8dc8.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.419] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/02701c239.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.424] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/0281aba7b.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.429] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/028eb44d1.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.437] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/028ed7768.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.445] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/0294f23c0.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.452] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/02b906933.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.458] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/02bf279c9.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.462] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/02c79bfcb.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.469] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/02d18b8a4.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.477] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/02d8c6b30.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.483] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/031627893.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.502] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/031f334ec.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.506] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/0340e13c4.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.519] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/03461f8e0.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.524] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/034941f9d.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.528] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/035021da2.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.534] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/0360edfb8.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.540] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/036c7d18c.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.563] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/037fca267.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.567] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/03860f6a9.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.586] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/0386ce84b.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.600] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/0391d44d6.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.605] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/039577d49.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.612] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/03ab4e3ea.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.617] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/03ca4d04c.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.646] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/03db6bbc3.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.652] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/03faf7462.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.657] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/04055fd3e.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.663] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/04072b39a.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.670] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/041187764.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.683] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/041a93b6d.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.688] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/04246167f.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.695] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/044700866.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.700] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/04594d04e.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.706] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/046282f58.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.710] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/047fa15d0.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.717] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/048d14d3f.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.723] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/0498abd18.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.752] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/049bad998.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.765] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/04a06d744.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.772] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/04a4777e9.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.778] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/04a5009fa.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.790] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/04ae7853c.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.799] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/04d49c95d.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.805] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/05184e71b.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.810] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/0518e79e9.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.815] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/051f0d825.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.826] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/0526d780c.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.833] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/052838084.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.837] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/052ac9a54.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.843] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/0534f1b45.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.853] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/05396b495.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.861] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/053e9a29c.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.865] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/054190eb2.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.878] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/0576d3847.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.884] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/057b89dd5.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.891] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/058a1e3b8.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.897] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/059327fe3.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.902] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/05a024a74.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.916] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/05d6bccf8.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.922] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/05f5e7366.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.926] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/0602f0520.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.932] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/0606395c5.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.949] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/062167783.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.959] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/063571c5c.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.964] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/0645d69f9.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.968] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/066ecd182.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.978] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/06713b712.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@16.999] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/068587112.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.007] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/0696cfa05.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.028] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/06ad83bac.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.047] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/06ae96c30.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.070] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/06aed81ba.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.078] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/06b384e78.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.084] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/06b49e34f.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.088] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/06d0fbb0c.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.094] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/06d3a99cb.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.117] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/06e55cb16.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.121] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/06e6582af.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.134] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/06e7b157a.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.140] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/06eb2151d.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.144] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/06f4583b1.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.148] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/06f52f4dd.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.157] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/06fb3a6e5.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.162] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/0712fbd90.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.167] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/0739e9688.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.179] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/07732248e.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.184] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/079054aa2.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.190] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/07a5651ce.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.204] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/07b1a9644.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.207] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/07b627cb9.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.212] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/07ba16aba.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.227] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/07c8ba1d5.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.235] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/07c8c77a3.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.239] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/07c917711.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.248] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/07cb6d544.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.253] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/07cbfd1f8.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.261] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/07cd0a3e9.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.271] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/0803acf1f.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.276] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/0808a098b.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.279] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/080d6f77f.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.287] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/0817e2da4.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@17.298] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/0841074c1.jpg'): can't open/read file: check file path/integrity
# ...
# [ WARN:0@109.420] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/fe335d9b8.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.425] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/fe65bce69.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.431] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/fe6f8e502.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.437] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/fe793c552.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.447] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/fe7b99496.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.452] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/fe90516f3.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.458] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/fe96a088d.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.466] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/fea2f6ad2.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.471] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/fea3da755.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.475] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/fea8e46ad.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.481] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/feb2cfa94.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.488] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/febd24f9a.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.507] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/fec4b10d0.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.512] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/fec86da3c.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.517] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/fed23a483.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.529] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/fee93875b.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.539] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/feebe80d4.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.544] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/ff1020719.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.554] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/ff27b4b1b.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.559] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/ff300484e.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.567] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/ff44fa556.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.572] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/ff4ddccf9.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.584] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/ff52f9fe2.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.590] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/ff5483763.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.597] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/ff5590fbe.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.602] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/ff5c7f868.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.620] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/ff6bfada2.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.628] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/ff6cc90ca.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.635] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/ff933e271.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.643] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/ff96dfa95.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.652] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/ff9923932.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.656] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/ffb48ee43.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.679] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/ffbd081d5.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.693] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/ffc9fdf70.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.698] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/ffcf72ecf.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.704] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/fff02e9c5.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.710] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/fffe98443.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.715] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/ffff4eaa8.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.725] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/test/c3/ffffd67df.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.735] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train/c3/e30a322d7.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@109.735] global /private/var/folders/dz/9k387psn21d19_fbwx0s2yb00000gn/T/pip-install-cgmg49b_/opencv-contrib-python_1492629f56864bfbb712f58580000a13/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/data/segmentation/train_mask/c3/mask_e30a322d7.jpg'): can't open/read file: check file path/integrity
# mask images successfully generated!
#
# beginning augmentation for ClassId 3...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [7], in <module>
# ----> 1 data_preparation_cnn.prepare_data_for_class_id(df=defects,
#       2                                                image_dimension=DIMENSION,
#       3                                                seed=SEED,
#       4                                                class_id=3,
#       5                                                inverse_masks=True)
#
# File ~/neuefische/projects/CapstoneProject_SteelDefectDetection/Python_Scripts/data_preparation_cnn.py:264, in prepare_data_for_class_id(df, image_dimension, seed, class_id, inverse_masks)
#     261 image_ids = df_train.query('ClassId == @class_id').ImageId.values
#     262 num_augmentations = max(df_train.groupby('ClassId').count().ImageId)
# --> 264 augement_images_and_masks(image_ids=image_ids, num_augmentations=num_augmentations, class_id=class_id)
#     266 end = time.time()
#     268 print('data successfully prepared for the model!')
#
# File ~/neuefische/projects/CapstoneProject_SteelDefectDetection/Python_Scripts/data_preparation_cnn.py:209, in augement_images_and_masks(image_ids, num_augmentations, class_id)
#     206 #print(type(original_image))
#     207 original_mask = cv2.imread('/data/segmentation/train_mask/' + path_suffix + mask_id)
# --> 209 augmented = augment(image=original_image, mask=original_mask)
#     210 transformed_image = augmented['image']
#     211 transformed_mask = augmented['mask']
#
# File ~/neuefische/projects/CapstoneProject_SteelDefectDetection/.venv/lib/python3.9/site-packages/albumentations/core/composition.py:195, in Compose.__call__(self, force_apply, *args, **data)
#     193     raise KeyError("You have to pass data to augmentations as named arguments, for example: aug(image=image)")
#     194 if self.is_check_args:
# --> 195     self._check_args(**data)
#     196 assert isinstance(force_apply, (bool, int)), "force_apply must have bool or int type"
#     197 need_to_run = force_apply or random.random() < self.p
#
# File ~/neuefische/projects/CapstoneProject_SteelDefectDetection/.venv/lib/python3.9/site-packages/albumentations/core/composition.py:271, in Compose._check_args(self, **kwargs)
#     269 if internal_data_name in checked_single:
#     270     if not isinstance(data, np.ndarray):
# --> 271         raise TypeError("{} must be numpy array type".format(data_name))
#     272 if internal_data_name in checked_multi:
#     273     if data:
#
# TypeError: image must be numpy array type

# %% [markdown]
# ---
#
# ### CNN-Model

# %%
import tensorflow as tf
import segmentation_models as sm
import glob
import cv2
import os
import numpy as np
from matplotlib import pyplot as plt

# %%
BACKBONE = 'resnet34'
preprocess_input = sm.get_preprocessing(BACKBONE)

preprocess=sm.get_preprocessing('efficientnetb5')


#Resizing images is optional, CNNs are ok with large images
SIZE_X = 128 #Resize images (height  = X, width = Y)
SIZE_Y = 128

# %%
def get_image_list(image_id):
    #Capture training image info as a list
    train_images = []
    path_suffix = 'c' + str(image_id) + '/'

    for directory_path in glob.glob('data/segmentation/train_aug/' + path_suffix):
        for img_path in glob.glob(os.path.join(directory_path, "*.jpg")):
            #print(img_path)
            #break
            img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
            img = cv2.resize(img, (SIZE_Y, SIZE_X))
            #img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
            train_images.append(img)
            #train_labels.append(label)
    #Convert list to array for machine learning processing        
    train_images = np.array(train_images)
    
    return train_images

# %%
train_images = get_image_list(image_id=4)
train_images.shape

# %%
def get_mask_list(image_id):
    #Capture mask/label info as a list
    train_masks = [] 
    path_suffix = 'c' + str(image_id) + '/'

    for directory_path in glob.glob('data/segmentation/train_mask_aug/' + path_suffix):
        for mask_path in glob.glob(os.path.join(directory_path, "*.jpg")):
            mask = cv2.imread(mask_path, 0)       
            mask = cv2.resize(mask, (SIZE_Y, SIZE_X))
            #mask = cv2.cvtColor(mask, cv2.COLOR_RGB2BGR)
            train_masks.append(mask)
            #train_labels.append(label)
    #Convert list to array for machine learning processing          
    train_masks = np.array(train_masks)
    
    return train_masks

# %%
train_masks = get_mask_list(image_id=4)
train_masks.shape

# %%
#Use customary x_train and y_train variables
X = train_images
Y = train_masks
print(X.shape, Y.shape)
Y = np.expand_dims(Y, axis=3) #May not be necessary.. leftover from previous code 
print(Y.shape)

# %%
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(X, Y, test_size=0.2, random_state=42)

# preprocess input
x_train = preprocess_input(x_train)
x_val = preprocess_input(x_val)

# %%
sm.set_framework('tf.keras')

sm.framework()
# define model
model = sm.Unet()#BACKBONE, encoder_weights='imagenet')
#model = sm.Unet('efficientnetb5',classes=1,activation='sigmoid',encoder_weights='imagenet')
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

#print(model.summary())

# %%
y_val.shape

# %%
history=model.fit(x_train, 
          y_train,
          batch_size=BATCH_SIZE, 
          epochs=10,
          verbose=1,
          validation_data=(x_val, y_val))

# %%
#accuracy = model.evaluate(x_val, y_val)
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

model.save('class2_test.h5')

# %%
history.history
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, acc, 'y', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
from tensorflow import keras
model = keras.models.load_model('class2_test.h5', compile=False)
#Test on a different image
#READ EXTERNAL IMAGE...
#data/segmentation/test/c1/1bed9264f.jpg
# test_img = cv2.imread('data/segmentation/test/c1/0d4866e3c.jpg', cv2.IMREAD_COLOR)   
# test_img = cv2.imread('data/segmentation/test/c1/1bed9264f.jpg', cv2.IMREAD_COLOR)  
test_img = cv2.imread('data/segmentation/test/c1/04e23e414.jpg', cv2.IMREAD_COLOR) 
test_img = cv2.resize(test_img, (SIZE_Y, SIZE_X))
test_img = cv2.cvtColor(test_img, cv2.COLOR_RGB2BGR)
print(test_img.shape)
test_img = np.expand_dims(test_img, axis=0)
print(test_img.shape)

# %%
prediction = model.predict(test_img)

# %%
#evaluation = model.evaluate(x_val, y_val, steps=10)

# %%
#evaluation

# %%
#View and Save segmented image
prediction_image = prediction.reshape(mask.shape)
plt.imshow(prediction_image, cmap='gray')
plt.imsave('data/segmentation/test0_segmented.jpg', prediction_image, cmap='gray')

# %%
img_path = 'data/segmentation/test_mask/c1/mask_04e23e414.jpg'
test_mask = cv2.imread(img_path, cv2.IMREAD_COLOR)       
test_mask = cv2.resize(test_mask, (SIZE_Y, SIZE_X))
plt.imshow(test_mask, cmap='gray')

# %% [markdown]
# ---
#
# ### Model from Oxford-Tut (TO-DO)

# %%
# ENCODER
base_model = tf.keras.applications.MobileNetV2(input_shape=[128, 128, 3], include_top=False)

# Use the activations of these layers
layer_names = [
                'block_1_expand_relu',   # 64x64
                'block_3_expand_relu',   # 32x32
                'block_6_expand_relu',   # 16x16
                'block_13_expand_relu',  # 8x8
                'block_16_project',      # 4x4
]
base_model_outputs = [base_model.get_layer(name).output for name in layer_names]

# Create the feature extraction model
down_stack = tf.keras.Model(inputs=base_model.input, outputs=base_model_outputs)

down_stack.trainable = False

# %%
# The decoder/upsampler is simply a series of upsample blocks implemented in TensorFlow examples.

up_stack = [
    pix2pix.upsample(512, 3),  # 4x4 -> 8x8
    pix2pix.upsample(256, 3),  # 8x8 -> 16x16
    pix2pix.upsample(128, 3),  # 16x16 -> 32x32
    pix2pix.upsample(64, 3),   # 32x32 -> 64x64
]

# %%
def unet_model(output_channels:int):
    inputs = tf.keras.layers.Input(shape=[128, 128, 3])

    # Downsampling through the model
    skips = down_stack(inputs)
    x = skips[-1]
    skips = reversed(skips[:-1])

    # Upsampling and establishing the skip connections
    for up, skip in zip(up_stack, skips):
        x = up(x)
        concat = tf.keras.layers.Concatenate()
        x = concat([x, skip])

    # This is the last layer of the model
    last = tf.keras.layers.Conv2DTranspose(
          filters=output_channels, kernel_size=3, strides=2,
          padding='same')  #64x64 -> 128x128

    x = last(x)

    return tf.keras.Model(inputs=inputs, outputs=x)

# %%
OUTPUT_CLASSES = 2

model = unet_model(output_channels=OUTPUT_CLASSES)
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), # expects `one_hot`
              metrics=['accuracy'])

# %% [markdown]
# ---

# %%
# #!wget https://cdn.freecodecamp.org/project-data/sms/train-data.tsv
# train_file_path = "data/segmentation/train"

# train_data = tf.data.experimental.make_csv_dataset(train_file_path, 
#                                                    header=False, 
#                                                    field_delim='\t', 
#                                                    column_names=['label', 'text'], 
#                                                    batch_size=64, 
#                                                    label_name='label', 
#                                                    num_epochs=1, 
#                                                    ignore_errors=True)

# examples, labels = next(iter(train_data)) # Just the first batch.
# print("FEATURES: \n", examples, "\n")
# print("LABELS: \n", labels)

# encoder = keras.layers.TextVectorization(max_tokens=None, output_mode='int', output_sequence_length=160)
# encoder.adapt(train_data)

# %%
def get_dataset(df, complete=True):
    if complete:
        dataset = tf.data.Dataset.from_tensor_slices((tf.cast(df['FilePath'].values, tf.string),
                                                      tf.cast(df['Mask'].values.tolist(), tf.float32)
                                                     )
                                                    )
    else:
        dataset = tf.data.Dataset.from_tensor_slices((tf.cast(df['FilePath'][:3000].values, tf.string),
                                                      tf.cast(df['Mask'][:3000].values.tolist(), tf.float32)
                                                     )
                                                    )
    return dataset

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

#tf.enable_eager_execution()

# training_df = pd.DataFrame(
#     data={'FilePath': defects.FilePath[:50],
#           'Mask': defects.Mask[:50]
#          }
# )

training_dataset = get_dataset(X_train, complete=False)

# for features_tensor, target_tensor in training_dataset:
#     print(f'features:{features_tensor} target:{target_tensor}')
training_dataset

# %%
training_dataset

# %%
tf.data.Dataset.from_tensor_slices((defects.FilePath[:10], list(defects.Mask[:10])))

# %% [markdown]
# ---
#
# ### Build Dataset for Model

# %%
# build the dataset by re-esembling the splitted data
dataset = {'train': X_train.join(y_train), 'test': X_test.join(y_test)}

# %% [markdown]
# ---
#
# ### Prepare the Model

# %%
def normalize(input_image, input_mask):
    input_image = tf.cast(input_image, tf.float32) / 255.0
    input_mask -= 1
    return input_image, input_mask

# %%
def load_image(file_path, mask):
    raw = tf.io.read_file(file_path)
    image = tf.image.decode_png(raw, channels=3)
    
    input_image = image #tf.image.resize(image, (128, 128))
    input_mask = mask #tf.image.resize(mask,#.reshape(mask.shape[0], mask.shape[1]), (128, 128))

    input_image, input_mask = normalize(input_image, input_mask)

    return input_image, input_mask

# %%
TRAIN_LENGTH = len(set(X_train.ImageId)) # number of unique `ImageIds`
BATCH_SIZE = 64
BUFFER_SIZE = 1000
STEPS_PER_EPOCH = TRAIN_LENGTH // BATCH_SIZE

# %%
train_images = training_dataset.map(load_image, num_parallel_calls=tf.data.AUTOTUNE)
#test_images = dataset['test'].map(load_image, num_parallel_calls=tf.data.AUTOTUNE)

# %%
train_images

# %% [markdown]
# ---
# ### Testing

# %%
X_test.head()

# %%
# Generate `masks` for every image
masks = []

for i in range(len(defects.ClassId)):
    #print(defects.EncodedPixels[i])
    encoded_pixels = defects.EncodedPixels[i]
    class_id = defects.ClassId[i]
    mask = mask_conversion.decode_pixel(image_dimension=DIMENSION, 
                                        encoded_pixels=encoded_pixels, 
                                        class_id=class_id)
    masks.append([mask.reshape(mask.shape[0]*mask.shape[1])])
    

masks_ = pd.DataFrame(masks, columns=['Mask'])

# %%
defects = defects.join(masks_)

# %%
defects.head(3)

# %%
# Visualize some masks
for i in range(5):
    mask = defects.Mask[i].reshape(mask.shape[0], mask.shape[1])

    plt.figure(figsize=(25, 8))
    plt.axis("off")  
    ax = plt.subplot(5, 1, i + 1)

    plt.imshow(mask)

# %%
# encoded_pixels = defects.EncodedPixels[0]
# class_id = defects.ClassId[0]
# mask = mask_conversion.decode_pixel(image_dimension=DIMENSION, 
#                                     encoded_pixels=encoded_pixels, 
#                                     class_id=class_id)
# mask

# %%
mask_flat = mask.reshape(mask.shape[0]*mask.shape[1])
mask_unflat = mask_flat.reshape(mask.shape[0], mask.shape[1])

# %%
# (mask_unflat == mask).sum()

# %%
# defects.EncodedPixels[0]

# %%
"""FOR CLASSIFICATION"""

path = os.getcwd()
print(path)

# Normalize the color values between 0 and 1
train = ImageDataGenerator(rescale=1/255)
validation = ImageDataGenerator(rescale=1/255)

# Takes the path to a directory & generates batches of augmented data.
train_generator = train.flow_from_directory(path + '/data/segmentation/train/',
                                            target_size=(256,1600),   #150,150
                                            batch_size = 32,
                                            save_format='jpg',
                                            class_mode = 'sparse')

# Takes the path to a directory & generates batches of augmented data.
validation_generator = validation.flow_from_directory(path + '/data/segmentation/test/',
                                          target_size=(256,1600),
                                          batch_size = 32,
                                          class_mode = 'sparse')

# %% [markdown]
# ---
#
# ### Externalized functions

# %%
def create_train_test_dfs(df, seed):
    X = df.copy()
    y = X.pop('ClassId')

    # Split into train and test set 
    X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.3, random_state=seed)
    
    return X_train.join(y_train), X_test.join(y_test)

# %%
# Create a temp path for the train & test split
def create_train_test_folders(subfolder, class_id):
    print('preparing folders...')
    path = os.getcwd()
    #
    ## You might need to adjust the path to your local environment
    temp_path = path + "/data/" + subfolder
    path_suffix = 'c' + str(class_id)
    
    # make base folder structure
    try:
        os.mkdir(temp_path)
        
        os.mkdir(temp_path + '/train')
        os.mkdir(temp_path + '/train_aug')
        
        os.mkdir(temp_path + '/train_mask')
        os.mkdir(temp_path + '/train_mask_aug')
        
        os.mkdir(temp_path + '/test')
        os.mkdir(temp_path + '/test_mask')
        print('base folder structure created')
        
    except OSError:
        print('base folder structure exists')
    
    # make class specific sub-folder structure
    try:
        os.mkdir(temp_path + '/train/' + path_suffix)
        os.mkdir(temp_path + '/train_aug/' + path_suffix)
        os.mkdir(temp_path + '/train_mask/'+ path_suffix)
        os.mkdir(temp_path + '/train_mask_aug/'+ path_suffix)
        print(f'sub-folder structure for ClassId {class_id} created')
        
    except OSError:
        print(f'sub-folder structure for ClassId {class_id} already exists')
    
    # make class specific sub-folder structure for test
    try:
        os.mkdir(temp_path + '/test/' + path_suffix)
        os.mkdir(temp_path + '/test_mask/' + path_suffix)
        print(f'sub-foder structure for testing for ClassId {class_id} created')
        
    except OSError:
        print ("Directories already exist")
    else:
        print ("Successfully created the directories")
    print()

# %%
# Copy and Separate in Imgages in Test and Train Folder
def copy_images_to_train_test(df_train, df_test, subfolder, class_id=2):
    path = os.getcwd()
    path_suffix = 'c' + str(class_id) + '/'
    
    create_train_test_folders(subfolder, class_id)
    df_train = df_train.query('ClassId == @class_id')
    df_test = df_test.query('ClassId == @class_id')
    
    print('copying images to folders...')

    for i in range(len(df_train)):
        #print(path)
        # for training data
        origin_train_path = path + '/data/train_images/'
        source_file_train = df_train.iloc[i,1]
        #print(source_file_train)
        target_directory_train = path + '/data/' + subfolder + '/train/' + path_suffix
        #print(origin_train_path)
        #print(target_directory_train)
        
            
        # Copy The Files
        shutil.copy2(origin_train_path + source_file_train, target_directory_train + source_file_train)
        try:
            # for testing data
            origin_test_path = path + '/data/train_images/'
            source_file_test = df_test.iloc[i,1]
            target_directory_test = path + '/data/' + subfolder + '/test/' + path_suffix

            shutil.copy2(origin_test_path + source_file_test, target_directory_test + source_file_test)
        except:
            continue
    print(f'Images successfully copied to {subfolder}!')
    print()

# %% [markdown]
# #### Create Mask Pictures

# %%
import cv2
import pathlib

def create_mask_image(image, image_id, encoded_pixels, inverse_masks):
    # path = os.getcwd()
    # target_directory = '/data/segmentation/train_mask/c1/'
    image_name = 'mask_' + image_id
    
    # os.chdir(path + target_directory)
    #print(target_directory.split('/')[0])
    #print(path.joinpath(target_directory.split('/')[0], image_name))
    if inverse_masks:
        mask = mask_conversion.create_mask_with_class_id_inverted(DIMENSION,class_id=2,encoded_pixels=encoded_pixels)
    else:
        mask = mask_conversion.create_mask_with_class_id(DIMENSION,class_id=2,encoded_pixels=encoded_pixels)
    mask *= 255
    
    written = cv2.imwrite(image_name, mask)
    #print(written)

# %%
def generate_mask_images(df, class_id, train=True, inverse_masks=False):
    """generates and saves mask images for `ClassId` 2
    """
    print(f'generating mask images for ClassId {class_id} images...')
    image_ids = df.query('ClassId == @class_id').ImageId

    path = os.getcwd()
    path_suffix = 'c' + str(class_id) + '/'
    #print(path)
    if train:
        target_directory = '/data/segmentation/train_mask/' + path_suffix
    else:
        target_directory = '/data/segmentation/test_mask/' + path_suffix
    # switch to target directory for saving process
    os.chdir(path + target_directory)

    for image_id in image_ids:
        if train:
            image = cv2.imread('data/segmentation/train/' + path_suffix + image_id)
        else:
            image = cv2.imread('data/segmentation/test/' + path_suffix + image_id)
        encoded_pixels = defects.query('ImageId == @image_id and ClassId == @class_id')[['EncodedPixels']]
        encoded_pixels = encoded_pixels.EncodedPixels.values[0]
        create_mask_image(image, image_id, encoded_pixels, inverse_masks)
    # switch back to home directory
    os.chdir(path)
    
    print('mask images successfully generated!')
    print()

# %% [markdown]
# ---
#
# #### Albumentations

# %%
import albumentations as A

augment = A.Compose([
    #A.VerticalFlip(p=0.5),
    A.HorizontalFlip(p=0.5),
    # A.OneOf([
    #     A.ElasticTransform(alpha=120, sigma=120 * 0.05, alpha_affine=120 * 0.03, p=0.5),
    #     A.GridDistortion(p=0.5),
    #     A.OpticalDistortion(distort_limit=2, shift_limit=0.5, p=1)                  
    #     ], p=0.8),
    A.CLAHE(p=0.8),
    A.RandomBrightnessContrast(p=0.8),    
    A.RandomGamma(p=0.8)
])

# %% [markdown]
# #### Testing Augmentations

# %%
def visualize(image, mask, original_image=None, original_mask=None):
    fontsize = 18
    
    if original_image is None and original_mask is None:
        f, ax = plt.subplots(2, 1, figsize=(15, 12))

        ax[0].imshow(image)
        ax[1].imshow(mask)
    else:
        f, ax = plt.subplots(2, 2, figsize=(12, 5))

        ax[0, 0].imshow(original_image)
        ax[0, 0].set_title('Original image', fontsize=fontsize)
        
        ax[1, 0].imshow(original_mask)
        ax[1, 0].set_title('Original mask', fontsize=fontsize)
        
        ax[0, 1].imshow(image)
        ax[0, 1].set_title('Transformed image', fontsize=fontsize)
        
        ax[1, 1].imshow(mask)
        ax[1, 1].set_title('Transformed mask', fontsize=fontsize)

# %%
original_image = cv2.imread('data/segmentation/train/c1/060c3159e.jpg')
original_mask = cv2.imread('data/segmentation/train_mask/c1/mask_060c3159e.jpg')

augmented = augment(image=original_image, mask=original_mask)

transformed_image = augmented['image']
transformed_mask = augmented['mask']

# %% [markdown]
# If the image has multiple associated masks, you should use the `masks` argument instead of `mask`. In masks you should pass a list of masks.
#
# ```python
# transformed = transform(image=image, masks=masks)
# transformed_image = transformed['image']
# transformed_masks = transformed['masks']
# ```

# %%
visualize(transformed_image, transformed_mask, original_image, original_mask)

# %% [markdown]
# #### Apply Augmentations

# %%
import random
import os
import time

def augement_images_and_masks(image_ids, num_augmentations, class_id):
    print(f'beginning augmentation for ClassId {class_id}...')
    start = time.time()
    
    path = os.getcwd()
    path_suffix = 'c' + str(class_id) + '/'
    
    target_directory_image = '/data/segmentation/train_aug/' + path_suffix
    target_directory_mask = '/data/segmentation/train_mask_aug/' + path_suffix
    
    i = 1
    
    while i <= num_augmentations:
        #print(i)
        number = random.randint(0, len(image_ids) -1)
        image_id = image_ids[number]
        mask_id = 'mask_' + image_id
        #print(image_id, mask_id)
        
        original_image = cv2.imread('data/segmentation/train/' + path_suffix + image_id)
        #print(type(original_image))
        original_mask = cv2.imread('data/segmentation/train_mask/' + path_suffix + mask_id)
        
        augmented = augment(image=original_image, mask=original_mask)
        transformed_image = augmented['image']
        transformed_mask = augmented['mask']
        
        os.chdir(path + target_directory_image)
        written = cv2.imwrite('aug_' + str(i) + '_' + image_id, transformed_image)
        #print(written)
        
        os.chdir(path + target_directory_mask)
        written = cv2.imwrite('aug_' + str(i) + '_' + mask_id, transformed_mask)
        #print(written)
        
        os.chdir(path)
        
        i += 1
    end = time.time()
    print(f'augmented {num_augmentations} images of ClassId {class_id}')
    print('time required for augmentation:', end - start)

# %%
path = os.getcwd()
path

# %%
os.chdir(path)

# %%
from sys import argv
image_ids = Xy_train.query('ClassId == 2').ImageId.values
print(len(image_ids))
nr = 0
#for id_ in image_ids:
    #print(os.path.exists('data/segmentation/train/c1/' + id_))
    # if os.access('data/segmentation/train/c1/' + image_id, os.R_OK):
    #     continue
    # else:
    #     nr += 1
        
print(nr)

# %%
image_id = 'a41ba727f.jpg'
original_image = cv2.imread('data/segmentation/train/c1/' + image_id)
print(os.access('data/segmentation/train/c1/' + image_id, os.R_OK))
print(os.path.exists('data/segmentation/train/c1/' + image_id))
print('data/segmentation/train/c1/' + image_id)
plt.imshow(original_image)

# %% [markdown]
# ---

# %%
def prepare_data_for_class_id(df, image_dimension, seed, class_id, inverse_masks):
    """combines all data preparations:
    - creating required folder structure
    - copying images to folders according to train-test-split using `seed`
    - generating masks for all images of `class_id`
    - augmenting images and corresponding masks
    
    Input parameters:
    df            - data frame that contains all defects and the `FilePaths` to all images
    seed          - seed for `train_test_split`
    class_id      - id of defect class
    inverse_masks - if `True`, defect pixels will be white, pixels without defect will be black
    """
    
    print('Starting data preparations')
    print('-----'*10)
    
    start = time.time()
    # split data into train and test
    df_train, df_test = data_preparation_cnn.create_train_test_dfs(df, seed)
    
    subfolder = 'segmentation'
    # sort images according to train-test-split
    data_preparation_cnn.copy_images_to_train_test(df_train, df_test, subfolder, class_id)
    
    # generate mask images for train and test data
    data_preparation_cnn.generate_mask_images(df, class_id, image_dimension, train=True, inverse_masks=inverse_masks)
    data_preparation_cnn.generate_mask_images(df, class_id, image_dimension, train=False, inverse_masks=inverse_masks)
    
    # augment images and masks where needed
    image_ids = df_train.query('ClassId == @class_id').ImageId.values
    num_augmentations = max(df_train.groupby('ClassId').count().ImageId)
    
    data_preparation_cnn.augement_images_and_masks(image_ids=image_ids, 
                                                   num_augmentations=num_augmentations, 
                                                   class_id=class_id)
    end = time.time()
    
    print('data successfully prepared for the model!')
    print('time elapsed:', end-start)

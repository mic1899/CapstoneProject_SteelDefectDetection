# %%
from IPython.display import Image, display
import pandas as pd

# %%
listOfImageNames = ['./Data/train_images/0002cc93b.jpg']

for imageName in listOfImageNames:
    display(Image(filename=imageName))

# %%
df = pd.read_csv('./Data/train.csv')

# %%
df.head(2)
# Out:
#          ImageId  ClassId                                      EncodedPixels
# 0  0002cc93b.jpg        1  29102 12 29346 24 29602 24 29858 24 30114 24 3...
# 1  0007a71bf.jpg        3  18661 28 18863 82 19091 110 19347 110 19603 11...

# %%
ImageId = df.ImageId[0]
ClassId = df.ClassId[0]
EncodedPixels = str(df.EncodedPixels[0])

# %%
EncodedPixels = EncodedPixels.split()

# %%
int(EncodedPixels)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/7m/gzqddxc12d39hj1_p4b9yhq40000gn/T/ipykernel_63017/3459574815.py in <module>
# ----> 1 int(EncodedPixels)
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'list'
